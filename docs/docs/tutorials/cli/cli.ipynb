# %%
# !uv pip install --quiet git+https://github.com/rawwerks/dspy.git

# %% [markdown]
# with claude code headless mode (claude -p)
# https://code.claude.com/docs/en/headless

# %%
import dspy
from dspy.clients.cli_lm import CLILM


class SimpleQuery(dspy.Signature):
    question: str = dspy.InputField()
    answer: str = dspy.OutputField()


lm = CLILM("claude -p --dangerously-skip-permissions")
dspy.configure(lm=lm)

predictor = dspy.Predict(SimpleQuery)
question = "What is the biggest file in this directory?"
result = predictor(question=question)

print(f"Question: {question}")
print(f"Claude answer: {result.answer}")
# Out:
# Question: What is the biggest file in this directory?
# Claude answer: The biggest file in this directory is `cli.ipynb` at 38K.

# %% [markdown]
# and with codex exec
#
# https://github.com/openai/codex/blob/main/docs/exec.md

# %%
lm = CLILM("codex exec")
dspy.configure(lm=lm)

result = predictor(question=question)

print(f"Question: {question}")
print(f"Codex answer: {result.answer}")
# Out:
# Reading prompt from stdin...
# OpenAI Codex v0.56.0 (research preview)
# --------
# workdir: /Users/raymondweitekamp/Documents/GitHub/dspy/docs/docs/tutorials/cli
# model: gpt-5-codex
# provider: openai
# approval: never
# sandbox: workspace-write [workdir, /tmp, $TMPDIR]
# reasoning effort: high
# reasoning summaries: auto
# session id: 019a6574-16a3-7ab1-b054-5fc941f178f1
# --------
# user
# SYSTEM:
# Your input fields are:
# 1. `question` (str):
# Your output fields are:
# 1. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## question ## ]]
# {question}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Given the fields `question`, produce the fields `answer`.
#
# USER:
# [[ ## question ## ]]
# What is the biggest file in this directory?
#
# Respond with the corresponding output fields, starting with the field `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
# thinking
# **Planning command to find largest file**
# exec
# bash -lc 'find . -maxdepth 1 -type f -exec stat -f "%z %N" {} + | sort -nr | head -n 1' in /Users/raymondweitekamp/Documents/GitHub/dspy/docs/docs/tutorials/cli succeeded in 720ms:
# find: sysconf(_SC_ARG_MAX): Operation not permitted
# find: no space for arguments
#
# thinking
# **Handling large argument lists with find and xargs**
# exec
# bash -lc 'find . -maxdepth 1 -type f -print0 | xargs -0 stat -f "%z %N" | sort -nr | head -n 1' in /Users/raymondweitekamp/Documents/GitHub/dspy/docs/docs/tutorials/cli succeeded in 664ms:
# xargs: sysconf(_SC_ARG_MAX) failed
#
# thinking
# **Improving file processing approach**
# exec
# bash -lc "find . -maxdepth 1 -type f -print0 | while IFS= read -r -d '' file; do stat -f \"%z %N\" \""'$file"; done | sort -nr | head -n 1' in /Users/raymondweitekamp/Documents/GitHub/dspy/docs/docs/tutorials/cli succeeded in 500ms:
# 39280 ./cli.ipynb
#
# thinking
# **Preparing formatted response**
# codex
# [[ ## answer ## ]]
# The largest file is `cli.ipynb` at 39,280 bytes.
#
# [[ ## completed ## ]]
# tokens used
# 2,859
# Question: What is the biggest file in this directory?
# Codex answer: The largest file is `cli.ipynb` at 39,280 bytes.

# %% [markdown]
# sometimes you need to insert the prompt into the argv of the cli command

# %%
lm = CLILM('claude -p "{prompt}" --dangerously-skip-permissions')
dspy.configure(lm=lm)

result = predictor(question=question)

print(f"Question: {question}")
print(f"Claude answer: {result.answer}")
# Out:
# Question: What is the biggest file in this directory?
# Claude answer: The biggest file in this directory is `cli.ipynb` with a size of 8.8KB.
